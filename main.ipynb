# %%
from board import Board
from search import alphabeta_search
import time

# %%
def game_loop(size):
    
    b = Board.initial_board(size)
    while True:
        start = time.time()
        print(b)
        if (b.is_terminal_state()):
            winner = b.winner()
            if winner == 0:
                print("It's a tie")
                
            else:
                print('Player {} has won'.format(winner))
                
            break
        b = alphabeta_search(b)
        stop = time.time()
        print("Total Time Taken : {}".format(stop-start))

# %%
if __name__ == '__main__':
    
    print("Lines Of Action")
    print("Enter the size of the board\n")
    
    size_of_board = int(input())
    
    game_loop(size_of_board)
# Out:
# Lines Of Action
# Enter the size of the board
#  6
# ┌─|─|─|─|─|─|┐
# │ bbbb │
# │w    w│
# │w    w│
# │w    w│
# │w    w│
# │ bbbb │
# └─|─|─|─|─|─|┘
# to move: 1
# Total Time Taken : 0.5539982318878174
# ┌─|─|─|─|─|─|┐
# │  bbb │
# │w    w│
# │w  b w│
# │w    w│
# │w    w│
# │ bbbb │
# └─|─|─|─|─|─|┘
# to move: 2
# Total Time Taken : 0.6840388774871826
# ┌─|─|─|─|─|─|┐
# │  bbb │
# │w    w│
# │w  w w│
# │w    w│
# │w     │
# │ bbbb │
# └─|─|─|─|─|─|┘
# to move: 1
# Total Time Taken : 0.6849980354309082
# ┌─|─|─|─|─|─|┐
# │   bb │
# │w    w│
# │b  w w│
# │w    w│
# │w     │
# │ bbbb │
# └─|─|─|─|─|─|┘
# to move: 2
# Total Time Taken : 0.43096494674682617
# ┌─|─|─|─|─|─|┐
# │   bb │
# │     w│
# │b  w w│
# │w w  w│
# │w     │
# │ bbbb │
# └─|─|─|─|─|─|┘
# to move: 1
# Total Time Taken : 0.4689958095550537
# ┌─|─|─|─|─|─|┐
# │   bb │
# │     w│
# │   b w│
# │w w  w│
# │w     │
# │ bbbb │
# └─|─|─|─|─|─|┘
# to move: 2
# Total Time Taken : 0.6053390502929688
# ┌─|─|─|─|─|─|┐
# │   bb │
# │     w│
# │   b w│
# │  w  w│
# │w     │
# │ bwbb │
# └─|─|─|─|─|─|┘
# to move: 1
# Total Time Taken : 0.4504213333129883
# ┌─|─|─|─|─|─|┐
# │   bb │
# │     w│
# │   b w│
# │  wb w│
# │w     │
# │  wbb │
# └─|─|─|─|─|─|┘
# to move: 2
# Total Time Taken : 0.41804075241088867
# ┌─|─|─|─|─|─|┐
# │   bb │
# │     w│
# │   b w│
# │  wbww│
# │w     │
# │   bb │
# └─|─|─|─|─|─|┘
# to move: 1
# Total Time Taken : 0.35200047492980957
# ┌─|─|─|─|─|─|┐
# │   b  │
# │     w│
# │   b w│
# │  wbbw│
# │w     │
# │   bb │
# └─|─|─|─|─|─|┘
# to move: 2
# Total Time Taken : 0.2519998550415039
# ┌─|─|─|─|─|─|┐
# │   b  │
# │      │
# │   b w│
# │  wwbw│
# │w     │
# │   bb │
# └─|─|─|─|─|─|┘
# to move: 1
# Total Time Taken : 0.19599604606628418
# ┌─|─|─|─|─|─|┐
# │      │
# │      │
# │   b b│
# │  wwbw│
# │w     │
# │   bb │
# └─|─|─|─|─|─|┘
# to move: 2
# Total Time Taken : 0.2020092010498047
# ┌─|─|─|─|─|─|┐
# │      │
# │      │
# │   b b│
# │  wwb │
# │w     │
# │   wb │
# └─|─|─|─|─|─|┘
# to move: 1
# Total Time Taken : 0.07799649238586426
# ┌─|─|─|─|─|─|┐
# │      │
# │      │
# │     b│
# │  wwb │
# │w    b│
# │   wb │
# └─|─|─|─|─|─|┘
# to move: 2
# Player 1 has won
